# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_healthcare = pd.read_csv('healthcare_eda_dataset (1).csv')
df_healthcare.head()
# Out:
#   Patient_ID  Age   BMI  Systolic_BP  Diastolic_BP  Cholesterol  Glucose  \
# 0       P001   69  19.0          134            76          269      100
# 1       P002   32  25.9           90            74          235      129
# 2       P003   78  28.5          146            70          284      105
# 3       P004   38  29.3          119            72          275      122
# 4       P005   41  26.4          127            70          220      124
#
#    Heart_Rate  Exercise_Hours_Per_Week  Hospital_Visits_Last_Year  \
# 0          78                      4.3                          0
# 1          73                      1.3                          2
# 2          75                      7.0                          1
# 3          95                      0.6                          2
# 4          63                      4.9                          2
#
#    Disease_Risk_Score
# 0                54.3
# 1                54.8
# 2                67.6
# 3                50.6
# ...

# %%
clinical_summary = df_healthcare[['Age','BMI','Cholesterol','Disease_Risk_Score']].describe()

print(clinical_summary)
# Out:
#              Age         BMI  Cholesterol  Disease_Risk_Score
# count  250.00000  250.000000   250.000000          250.000000
# mean    50.42000   26.813600   256.872000           51.534800
# std     20.17662    4.821952    36.429715           12.793464
# min     18.00000   11.900000   164.000000           18.900000
# 25%     33.00000   23.700000   228.250000           41.050000
# 50%     50.00000   26.600000   255.000000           52.150000
# 75%     69.00000   30.400000   286.000000           60.450000
# max     84.00000   41.300000   344.000000           83.000000

# %%
correlation_matrix = df_healthcare[[
    "Age","BMI","Cholesterol","Glucose",
    "Exercise_Hours_Per_Week","Disease_Risk_Score"
]].corr()

print("--- Clinical Correlation Matrix ---")
print(correlation_matrix)
# Out:
# --- Clinical Correlation Matrix ---
#                               Age       BMI  Cholesterol   Glucose  \
# Age                      1.000000  0.040006     0.750109  0.067957
# BMI                      0.040006  1.000000     0.313319  0.423070
# Cholesterol              0.750109  0.313319     1.000000  0.193627
# Glucose                  0.067957  0.423070     0.193627  1.000000
# Exercise_Hours_Per_Week -0.049590  0.011361    -0.080012 -0.028300
# Disease_Risk_Score       0.682078  0.276206     0.651560  0.275322
#
#                          Exercise_Hours_Per_Week  Disease_Risk_Score
# Age                                    -0.049590            0.682078
# BMI                                     0.011361            0.276206
# Cholesterol                            -0.080012            0.651560
# Glucose                                -0.028300            0.275322
# Exercise_Hours_Per_Week                 1.000000           -0.241321
# ...

# %%
x = np.linspace(0, 10, 100)
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
y1 = x ** 2 # quadratic growth function f(x) = x^2
y2 = 10 * x # linear baseline growth g(x) = 10x

# %%
plt.plot(x,y1, label='f(x) = x^2', linewidth=2, color='blue', linestyle='--')
plt.plot(x,y2, label='g(x) = 10x', linewidth=2, color='red', linestyle='-.')

plt.title('Line Plot of f(x) and g(x)', fontsize=16, fontweight='bold')
plt.xlabel('Independent Variable (x Range)', fontsize=14)
plt.ylabel('Computed Output (y Values)', fontsize=14)
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)


plt.savefig('line_plot_function.png', bbox_inches='tight', dpi=300)

# %%
plt.close()

# %% [markdown]
# **Scatter plot**: A scatter plot is a type of data visualization that uses dots to represent the values of two different variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are useful for identifying relationships or correlations between two variables.

# %%
df_election = pd.read_csv('election_data.csv')
df_district = pd.read_csv('district_data (1).csv')
df_province = pd.read_csv('province_data.csv')

df_master = pd.merge(
df_election, df_district, on='district_id', how='inner').merge(
df_province, on='province_id', how='left')

# %%
# plot candidate age against the number of votes received
plt.scatter(df_master['age'], df_master['votes'], color='purple', alpha=0.5, edgecolor='none', s=30)
plt.title('Candidate Age vs. Votes Received', fontsize=14, fontweight='bold')
plt.xlabel('Candidate Age', fontsize=12)
plt.ylabel('Number of Votes Received', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.savefig('scatter_plot_age_votes.png', bbox_inches='tight')
plt.close()

# %%
party_count = df_master['party'].value_counts().head(5).sort_values(ascending=True)
party_count
# Out:
# party
# Communist Party of Nepal           164
# CPN (Unified Marxist-Leninist)     164
# Rastriya Swatantra Party           164
# Nepali Congress                    165
# Independent                       1143
# Name: count, dtype: int64

# %%
plt.barh(party_count.index, party_count.values, color='teal', edgecolor='black', height=0.6)
plt.title('Top 5 Political Parties by Candidate Volume', fontsize=14, fontweight='bold')
plt.xlabel("Total Registered Candidates", fontsize=12)
plt.ylabel("Political Party", fontsize=12)
plt.savefig('bar_chart_top_parties.png', bbox_inches='tight')
plt.show()

# %%
gender_distribution = df_master['gender'].value_counts()
gender_distribution
# Out:
# gender
# male      3017
# female     388
# other        1
# Name: count, dtype: int64

# %%
plt.pie(
gender_distribution.values,
labels = gender_distribution.index,
autopct='%1.1f%%',
colors=['skyblue', 'lightcoral', 'pink'],
startangle=90,
pctdistance=0.85
)
# Out:
# ([<matplotlib.patches.Wedge at 0x165feb07c50>,
# ...
#  [Text(-0.38626738758672724, -1.0299502440831427, 'male'),
#   Text(0.3872172019350454, 1.0295935307321984, 'female'),
#   Text(0.001013002642565505, 1.0999995335570132, 'other')],
#  [Text(-0.29847934495338013, -0.7958706431551557, '88.6%'),
#   Text(0.2992132924043532, 0.7955950010203351, '11.4%'),
#   Text(0.0007827747692551629, 0.8499996395667828, '0.0%')])

# %%
plt.hist(df_master['age'], bins=15, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title("National Candidate Age Distribution", fontsize=14, fontweight='bold')
plt.xlabel("Candidate Age", fontsize=12)
plt.ylabel("Number of Candidates", fontsize=12)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)

plt.savefig('histogram_candidate_age.png', bbox_inches='tight')

# %%
province_order = df_master.groupby('province_name')['age'].median().sort_values().index 
sns.set_theme(style='whitegrid')
sns.boxplot(
    data = df_master,
    x = 'age',
    y = 'province_name',
    hue = 'province_name',
    order = province_order,
    palette='Set3'
)
plt.title("Candidate Age Distribution by Province", fontsize=14, fontweight='bold')
plt.xlabel("Candidate Age (Years)", fontsize=12)
plt.ylabel("Province Name", fontsize=12)

plt.savefig('boxplot_age_province.png', bbox_inches='tight')

# %%
# subplots example 
x = np.array([1, 2, 3, 4, 5])

fig,axs = plt.subplots(2,2)

axs[0,0].plot(x,x*2,color='red')
axs[0,0].set_title('x*2')

axs[0,1].bar(x,x**2,color='blue')
axs[0,1].set_title('x**2')

axs[1,0].scatter(x,x**3,color='green')
axs[1,0].set_title('x**3')

axs[1,1].hist(x,x**4,color='purple')
axs[1,1].set_title('x**4')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# Read the regression training dataset
df = pd.read_csv('regression_training_dataset.csv')
df.shape
df.head()
# Out:
#    StudyHoursPerWeek  AttendancePercent  AssignmentsCompleted  \
# 0                  7                 81                    15
# 1                  4                 70                    18
# 2                  8                 75                     4
# 3                  5                 92                    13
# 4                  7                 68                     4
#
#    ExperienceYears  PerformanceScore
# 0                4            131.41
# 1                5            104.00
# 2                5            109.93
# 3                2            118.35
# 4                6             96.22

# %%
x = df.drop(columns=['PerformanceScore'])
y = df['PerformanceScore']

# %%
y_stratified_bins = pd.qcut(y, q=5, labels=False)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    x, y,
    test_size=0.20,
    random_state=42,
    stratify=y_stratified_bins
)

# %%
y_train_val_bins = pd.qcut(y_train_val, q=5, labels=False)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val,
    test_size=0.25,
    random_state=42,
    stratify=y_train_val_bins
)

# %%
print(f"Training set size: {X_train.shape[0]} samples")
print(f"Validation set size: {X_val.shape[0]} samples")
print(f"Test set size: {X_test.shape[0]} samples")
# Out:
# Training set size: 120 samples
# Validation set size: 40 samples
# Test set size: 40 samples

# %%
print(y.mean())
print(y_train.mean())
print(y_val.mean())
print(y_test.mean())
# Out:
# 111.31239999999998
# 111.31349999999999
# 111.08624999999999
# 111.53524999999999

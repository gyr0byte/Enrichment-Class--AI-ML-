# %%
customer_id = 1014
customer_name = "Sarah Jenkins"
monthly_spend = 89.50
is_premium_member = True

# %%
total_yearly_spend = monthly_spend * 12
discounted_spend = monthly_spend - (monthly_spend * 0.10)

# %%
print("Customer", customer_name)
print("Total Yearly Spend:", total_yearly_spend)
print("Discounted Price:", discounted_spend)
# Out:
# Customer Sarah Jenkins
# Total Yearly Spend: 1074.0
# Discounted Price: 80.55

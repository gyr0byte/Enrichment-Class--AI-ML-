# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv('customer_churn_ann_dataset.csv')

# %%
df.head()
# Out:
#   CustomerID  Age  TenureMonths  ...  PaperlessBilling  NumSupportTickets Churn
# 0      C0001   38            20  ...               Yes                  8    No
# 1      C0002   31             5  ...               Yes                  1    No
# 2      C0003   32             8  ...               Yes                  4    No
# 3      C0004   44            19  ...               Yes                  5   Yes
# 4      C0005   24            71  ...                No                  5   Yes
#
# [5 rows x 12 columns]

# %%
df = df.drop(columns=['CustomerID'])

# %%
df.head()
# Out:
#    Age  TenureMonths  MonthlyCharges  ...  PaperlessBilling NumSupportTickets Churn
# 0   38            20              70  ...               Yes                 8    No
# 1   31             5              31  ...               Yes                 1    No
# 2   32             8              93  ...               Yes                 4    No
# 3   44            19              89  ...               Yes                 5   Yes
# 4   24            71             111  ...                No                 5   Yes
#
# [5 rows x 11 columns]

# %%
# Data Cleaning
df['InternetService'] = df['InternetService'].fillna('Unknown')

# %%
X_raw = df.drop(columns=['Churn'])

# %%
y = df['Churn'].map({'Yes': 1, 'No': 0})
